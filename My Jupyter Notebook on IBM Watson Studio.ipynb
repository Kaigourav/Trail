# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __GOURAV__
# I Want to be Data Scientist

# %% [markdown]
# _I am interested in data science because I would love to contribute towards affordable and Quality World in Future_

# %% [markdown]
# ### My Code will SUM up two numbers

# %%
2+8
# Out:
# 10

# %% [markdown]
# *  My Code Did its job
# ***
# 1. It got the answer correct
# 1. I didnt show any error
# ***
